# %%
import pandas
import missingno as msno
import numpy as np
from scipy import stats

# %% [markdown]
# ### Missing value analysis
#
# Missing Completely at Random:  There is no pattern in the missing data on any variables. This is the best you can hope for.
#
# Missing at Random: There is a pattern in the missing data but not on your primary dependent variables such as likelihood to recommend or SUS Scores.
#
# Missing Not at Random: There is a pattern in the missing data that affect your primary dependent variables. For example, lower-income participants are less likely to respond and thus affect your conclusions about income and likelihood to recommend.
#
# Missing not at random is your worst-case scenario. Proceed with caution.

# %%
# %matplotlib inline
full_training_set = pandas.read_csv('data/training_set_VU_DM_2014.csv')
print("Dataset loaded")
# Out:
# Dataset loaded

# %% [markdown]
# After loading the dataset a plot can be shown analyse the missing values. With the help of missingno a interesting plot is made.

# %%
msno.matrix(full_training_set)

# %% [markdown]
# Counting the amount of missing values in the dataset gives an insight if values should be removed Entirely or not.

# %%
list_of_missing_data = full_training_set.isnull().sum()

# %% [markdown]
# T-tests are used to figure out if the data is completely at random and thus the entire column can be removed. When there is a definitive correlation between the to predict values click_bool and/or booking_bool the missing values have to be filled in.

# %%
cat1 = full_training_set[full_training_set['comp1_inv'].isnull()==True]['click_bool']
cat2 = full_training_set[full_training_set['comp1_inv'].isnull()==False]['click_bool']

print(full_training_set['click_bool'].sum()/4958347)
print(cat1.mean())
print(cat2.mean())




cat1 = full_training_set[full_training_set['comp1_inv'].isnull()==True]['booking_bool']
cat2 = full_training_set[full_training_set['comp1_inv'].isnull()==False]['booking_bool']


print(full_training_set['booking_bool'].mean())
print(cat1.mean())
print(cat2.mean())
# Out:
# 0.04474858254172207
# 0.0447590575523299
# 0.04435816886515024
# 0.027910511305481445
# 0.027965402498515157
# 0.025864663975486073

# %%
for index_val, val in zip(list_of_missing_data.index,list_of_missing_data):
    # If there is missing data we can do a t-test.
    if val > 0 and if index_val != "gross_bookings_usd":
        print(index_val)
        cat1 = full_training_set[full_training_set[index_val].isnull()==True]['click_bool']
        cat2 = full_training_set[full_training_set[index_val].isnull()==False]['click_bool']

        print("average for null values: "+ str(cat1.mean()))
        print("average for not null values: "+ str(cat2.mean()))
        
#         t2, p2 = stats.ttest_ind(cat1,cat2,equal_var=False)
#         print("t-value click boolean = " + str(t2))
#         print("p-value click boolean = " + str(p2))
        
        cat1 = full_training_set[full_training_set[index_val].isnull()==True]['booking_bool']
        cat2 = full_training_set[full_training_set[index_val].isnull()==False]['booking_bool']

        print("average for null values: "+ str(cat1.mean()))
        print("average for not null values: "+ str(cat2.mean()))
#         t2, p2 = stats.ttest_ind(cat1,cat2,equal_var=False)
#         print("t-value booking boolean = " + str(t2))
#         print("p-value booking boolean = " + str(p2))
# Out:
# visitor_hist_starrating
# average for null values: 0.0447759164437294
# average for not null values: 0.04423780899367124
# average for null values: 0.02747318006808059
# average for not null values: 0.03608267888480383
# visitor_hist_adr_usd
# average for null values: 0.044773841910893515
# average for not null values: 0.04427878002118678
# average for null values: 0.0274699550023707
# average for not null values: 0.0361044792638386
# prop_review_score
# average for null values: 0.03476371537208039
# average for not null values: 0.0447634338473794
# average for null values: 0.015752308527973928
# average for not null values: 0.027928595190086496
# prop_location_score2
# average for null values: 0.024469252018621577
# average for not null values: 0.050465111288808505
# average for null values: 0.013274660933940356
# average for not null values: 0.03203620269808757
# srch_query_affinity_score
# average for null values: 0.04477928075362302
# average for not null values: 0.04429972968374889
# average for null values: 0.027473954096809246
# average for not null values: 0.034293617637977857
# orig_destination_distance
# average for null values: 0.04636636061356577
# average for not null values: 0.04397228527129007
# average for null values: 0.02779543495324615
# average for not null values: 0.02796573115280557
# comp1_rate
# average for null values: 0.04474107957209972
# average for not null values: 0.04505127991328275
# average for null values: 0.027947570455378278
# average for not null values: 0.02641540898857667
# comp1_inv
# average for null values: 0.0447590575523299
# average for not null values: 0.04435816886515024
# average for null values: 0.027965402498515157
# average for not null values: 0.025864663975486073
# comp1_rate_percent_diff
# average for null values: 0.04474591213485123
# average for not null values: 0.04488611696438971
# average for null values: 0.027937000453133572
# average for not null values: 0.026546236194792405
# comp2_rate
# average for null values: 0.045622640544709284
# average for not null values: 0.043482104755733275
# average for null values: 0.027234100573512745
# average for not null values: 0.02889060549066713
# comp2_inv
# average for null values: 0.04556557492402968
# average for not null values: 0.04366396919825618
# average for null values: 0.027091190554150203
# average for not null values: 0.02899821571829661
# comp2_rate_percent_diff
# average for null values: 0.04437804697702851
# average for not null values: 0.04768102862443774
# average for null values: 0.02735756883802741
# average for not null values: 0.03228653921522801
# comp3_rate
# average for null values: 0.04507252941611111
# average for not null values: 0.04402563273648755
# average for null values: 0.027187615633959578
# average for not null values: 0.029523792143326417
# comp3_inv
# average for null values: 0.04513029588278496
# average for not null values: 0.043983912682693416
# average for null values: 0.02716398622827835
# average for not null values: 0.029405992767975578
# comp3_rate_percent_diff
# average for null values: 0.044445385738649666
# average for not null values: 0.04762509068373953
# average for null values: 0.02738393285104391
# average for not null values: 0.03290630016687923
# comp4_rate
# average for null values: 0.044560391608716374
# average for not null values: 0.04759611943600388
# average for null values: 0.027866236046724887
# average for not null values: 0.028580444924490366
# comp4_inv
# average for null values: 0.04452959292553943
# average for not null values: 0.047689160602101474
# average for null values: 0.02786626343212233
# average for not null values: 0.028504668817999027
# comp4_rate_percent_diff
# average for null values: 0.04467378084590827
# average for not null values: 0.04750316586058008
# average for null values: 0.02788454985135463
# average for not null values: 0.02886654562653525
# comp5_rate
# average for null values: 0.04514662785538167
# average for not null values: 0.04425854705758214
# average for null values: 0.027285712510425903
# average for not null values: 0.028679704082078032
# comp5_inv
# average for null values: 0.04515405489763221
# average for not null values: 0.04430216693078872
# average for null values: 0.02721404965579775
# average for not null values: 0.028677299344920807
# comp5_rate_percent_diff
# average for null values: 0.04451978603183486
# average for not null values: 0.04586856006248967
# average for null values: 0.027364637738605983
# average for not null values: 0.030582606803717518
# comp6_rate
# average for null values: 0.044521522024335604
# average for not null values: 0.049209475468131265
# average for null values: 0.02769981709087595
# average for not null values: 0.03204986737842328
# comp6_inv
# average for null values: 0.04450872626411667
# average for not null values: 0.04906581448102507
# average for null values: 0.027689956786466303
# average for not null values: 0.031880326160259945
# comp6_rate_percent_diff
# average for null values: 0.04465472536662106
# average for not null values: 0.0494936261359619
# average for null values: 0.02783775896085968
# average for not null values: 0.03158857903383451
# comp7_rate
# average for null values: 0.044457687800492744
# average for not null values: 0.04903154610144983
# average for null values: 0.027622017579585954
# average for not null values: 0.032158123723632304
# comp7_inv
# average for null values: 0.04445965547026516
# average for not null values: 0.048479050114751614
# average for null values: 0.027629090000380274
# average for not null values: 0.031544068547957195
# comp7_rate_percent_diff
# average for null values: 0.04460362933811801
# average for not null values: 0.04979244125184998
# average for null values: 0.027769225151416065
# average for not null values: 0.032826769663935315
# comp8_rate
# average for null values: 0.04606546420036473
# average for not null values: 0.04265871670108429
# average for null values: 0.02722036707846584
# average for not null values: 0.02900575690761087
# comp8_inv
# average for null values: 0.04598087277554796
# average for not null values: 0.04290660190198455
# average for null values: 0.027065709273189707
# average for not null values: 0.029173289298179677
# comp8_rate_percent_diff
# average for null values: 0.044728391108147886
# average for not null values: 0.0448912530704537
# average for null values: 0.02745707091578286
# average for not null values: 0.031114473020675742
# gross_bookings_usd
# average for null values: 0.0173215238227229
# average for not null values: 1.0
# average for null values: 0.0
# average for not null values: 1.0

# %%
for index_val, val in zip(list_of_missing_data.index,list_of_missing_data):
    # If there is missing data we can do a t-test.
    if val > 0 and if index_val != "gross_bookings_usd":
        print(index_val)
        cat2 = full_training_set[full_training_set[index_val].isnull()==False][index_val]

        print("new average for null values: "+ str(cat2.mean()))
